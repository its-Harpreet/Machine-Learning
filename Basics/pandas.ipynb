# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default='notebook'

# %%
## setting

pd.set_option("display.max_columns",None)

# %%
df=pd.read_csv("https://raw.githubusercontent.com/digipodium/Datasets/main/automobile.csv")

# %%
df.horsepower  # or df.['horsepower']
# Out:
# 0      111
# 1      111
# 2      154
# 3      102
# 4      115
#       ...
# 200    114
# 201    160
# 202    134
# 203    106
# 204    114
# Name: horsepower, Length: 205, dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'symboling', 'normalized-losses', 'make', 'fuel-type',
#        'aspiration', 'num-of-doors', 'body-style', 'drive-wheels',
#        'engine-location', 'wheel-base', 'length', 'width', 'height',
#        'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size',
#        'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower',
#        'peak-rpm', 'city-mpg', 'highway-mpg', 'price'],
#       dtype='object')

# %%
df['make'] #series
# Out:
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3             audi
# 4             audi
#           ...
# 200          volvo
# 201          volvo
# 202          volvo
# 203          volvo
# 204          volvo
# Name: make, Length: 205, dtype: object

# %%
cols=['price','body-style','engine-type','fuel-type']
df[cols] #subset of dataframe
# Out:
#      price   body-style engine-type fuel-type
# 0    13495  convertible        dohc       gas
# 1    16500  convertible        dohc       gas
# 2    16500    hatchback        ohcv       gas
# 3    13950        sedan         ohc       gas
# 4    17450        sedan         ohc       gas
# ..     ...          ...         ...       ...
# 200  16845        sedan         ohc       gas
# 201  19045        sedan         ohc       gas
# 202  21485        sedan        ohcv       gas
# 203  22470        sedan         ohc    diesel
# 204  22625        sedan         ohc       gas
#
# [205 rows x 4 columns]

# %%
df.shape
# Out:
# (205, 27)

# %%
# iloc is used for rows but can also be used for column

df.iloc[:,[1,2,5,8,9]]  #columns by their index
# Out:
#      symboling normalized-losses aspiration drive-wheels engine-location
# 0            3                 ?        std          rwd           front
# 1            3                 ?        std          rwd           front
# 2            1                 ?        std          rwd           front
# 3            2               164        std          fwd           front
# 4            2               164        std          4wd           front
# ..         ...               ...        ...          ...             ...
# 200         -1                95        std          rwd           front
# 201         -1                95      turbo          rwd           front
# 202         -1                95        std          rwd           front
# 203         -1                95      turbo          rwd           front
# 204         -1                95      turbo          rwd           front
#
# [205 rows x 5 columns]

# %%
df.iloc[:,:-1]  # all columns except last one
# Out:
#      Unnamed: 0  symboling normalized-losses         make fuel-type  \
# 0             0          3                 ?  alfa-romero       gas
# 1             1          3                 ?  alfa-romero       gas
# 2             2          1                 ?  alfa-romero       gas
# 3             3          2               164         audi       gas
# 4             4          2               164         audi       gas
# ..          ...        ...               ...          ...       ...
# 200         200         -1                95        volvo       gas
# 201         201         -1                95        volvo       gas
# 202         202         -1                95        volvo       gas
# 203         203         -1                95        volvo    diesel
# 204         204         -1                95        volvo       gas
#
#     aspiration num-of-doors   body-style drive-wheels engine-location  \
# 0          std          two  convertible          rwd           front
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         205 non-null    int64
#  1   symboling          205 non-null    int64
#  2   normalized-losses  205 non-null    object
#  3   make               205 non-null    object
#  4   fuel-type          205 non-null    object
#  5   aspiration         205 non-null    object
#  6   num-of-doors       205 non-null    object
#  7   body-style         205 non-null    object
#  8   drive-wheels       205 non-null    object
#  9   engine-location    205 non-null    object
#  10  wheel-base         205 non-null    float64
#  11  length             205 non-null    float64
#  12  width              205 non-null    float64
#  13  height             205 non-null    float64
#  14  curb-weight        205 non-null    int64
#  15  engine-type        205 non-null    object
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0   symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   102.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      0.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     51.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    102.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    153.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    204.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# ...

# %%
df.describe(include='object')  #shows non numerical values 

# count and freq should be different else that column is of no use
# Out:
#        normalized-losses    make fuel-type aspiration num-of-doors body-style  \
# count                205     205       205        205          205        205
# unique                52      22         2          2            3          5
# top                    ?  toyota       gas        std         four      sedan
# freq                  41      32       185        168          114         96
#
#        drive-wheels engine-location engine-type num-of-cylinders fuel-system  \
# count           205             205         205              205         205
# unique            3               2           7                7           8
# top             fwd           front         ohc             four        mpfi
# freq            120             202         148              159          94
#
#         bore stroke horsepower peak-rpm price
# count    205    205        205      205   205
# unique    39     37         60       24   187
# top     3.62   3.40         68     5500     ?
# ...

# %%
#replacing ? with NAN
 
df.replace('?',np.nan, inplace=True)

# %%
df.isna().sum() # checks for the NAN values
# Out:
# Unnamed: 0            0
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
df
# Out:
#      Unnamed: 0  symboling normalized-losses         make fuel-type  \
# 0             0          3               NaN  alfa-romero       gas
# 1             1          3               NaN  alfa-romero       gas
# 2             2          1               NaN  alfa-romero       gas
# 3             3          2               164         audi       gas
# 4             4          2               164         audi       gas
# ..          ...        ...               ...          ...       ...
# 200         200         -1                95        volvo       gas
# 201         201         -1                95        volvo       gas
# 202         202         -1                95        volvo       gas
# 203         203         -1                95        volvo    diesel
# 204         204         -1                95        volvo       gas
#
#     aspiration num-of-doors   body-style drive-wheels engine-location  \
# 0          std          two  convertible          rwd           front
# ...

# %%
# plotting a curve graph of 'curb-weight'

df['curb-weight'].plot()
# Out:
# <AxesSubplot:>

# %%
# plotting a histogram of 'curb-weight'

df['curb-weight'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# plotting a histogram of 'curb-weight'

df['curb-weight'].plot(kind='hist', bins=3)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
def check_weight(w):
    if w< 2000:
        return 'light'
    elif w < 3100:
        return 'medium'
    else:
        return 'heavy'

# %%
df['curb-weight'].apply(check_weight)
# Out:
# 0      medium
# 1      medium
# 2      medium
# 3      medium
# 4      medium
#         ...
# 200    medium
# 201    medium
# 202    medium
# 203     heavy
# 204    medium
# Name: curb-weight, Length: 205, dtype: object

# %%
# adds a column 'class' 
df['class']=df['curb-weight'].apply(check_weight)

# %%
df.head()
# Out:
#    Unnamed: 0  symboling normalized-losses         make fuel-type aspiration  \
# 0           0          3               NaN  alfa-romero       gas        std
# 1           1          3               NaN  alfa-romero       gas        std
# 2           2          1               NaN  alfa-romero       gas        std
# 3           3          2               164         audi       gas        std
# 4           4          2               164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two  convertible          rwd           front        88.6   168.8
# 2          two    hatchback          rwd           front        94.5   171.2
# 3         four        sedan          fwd           front        99.8   176.6
# 4         four        sedan          4wd           front        99.4   176.6
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'symboling', 'normalized-losses', 'make', 'fuel-type',
#        'aspiration', 'num-of-doors', 'body-style', 'drive-wheels',
#        'engine-location', 'wheel-base', 'length', 'width', 'height',
#        'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size',
#        'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower',
#        'peak-rpm', 'city-mpg', 'highway-mpg', 'price', 'class'],
#       dtype='object')

# %%
cols_to_remove=['Unnamed: 0',  'symboling', 'normalized-losses']
df.drop(columns= cols_to_remove)  # testing if the columns are removed
# Out:
#             make fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 0    alfa-romero       gas        std          two  convertible          rwd
# 1    alfa-romero       gas        std          two  convertible          rwd
# 2    alfa-romero       gas        std          two    hatchback          rwd
# 3           audi       gas        std         four        sedan          fwd
# 4           audi       gas        std         four        sedan          4wd
# ..           ...       ...        ...          ...          ...          ...
# 200        volvo       gas        std         four        sedan          rwd
# 201        volvo       gas      turbo         four        sedan          rwd
# 202        volvo       gas        std         four        sedan          rwd
# 203        volvo    diesel      turbo         four        sedan          rwd
# 204        volvo       gas      turbo         four        sedan          rwd
#
# ...

# %%
cols_to_remove=['Unnamed: 0',  'symboling', 'normalized-losses']
df.drop(columns= cols_to_remove, inplace=True)  # actually removing the columns

# %%
df.sort_values(by='price', ascending=False, inplace=True) #sort by price

# %%
px.scatter(data_frame=df, x='price', y='length')
# Out:
# <div>                            <div id="dbff520c-ed6b-40c8-9a97-a053ad0007e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dbff520c-ed6b-40c8-9a97-a053ad0007e6")) {                    Plotly.newPlot(                        "dbff520c-ed6b-40c8-9a97-a053ad0007e6",                        [{"hovertemplate":"price=%{x}<br>length=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["9995","9989","9988","9980","9960","9959","9895","9639","9549","9538","9495","9298","9295","9279","9279","9258","9233","9095","8949","8948","8921","8921","8845","8845","8778","8558","8499","8495","8495","8449","8358","8249","8238","8195","8189","8058","8013","7999","7995","
# ...
